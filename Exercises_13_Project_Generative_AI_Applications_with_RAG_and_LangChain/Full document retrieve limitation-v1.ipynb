# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Put Whole Document into Prompt and Ask the Model**

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Overview
# In recent years, the development of Large Language Models (LLMs) like GPT-3 and GPT-4 has revolutionized the field of natural language processing (NLP). These models are capable of performing a wide range of tasks, from generating coherent text to answering questions and summarizing information. Their effectiveness, however, is not without limitations. One significant constraint is the context window length, which affects how much information can be processed at once. LLMs operate within a fixed context window, measured in tokens, with GPT-3 having a limit of 4096 tokens and GPT-4 extending to 8192 tokens. When dealing with lengthy documents, attempting to input the entire text into the model's prompt can lead to truncation, where essential information is lost, and increased computational costs due to the processing of large inputs.
#
# These limitations become particularly pronounced when creating a retrieval-based question-answering (QA) assistant. The context length constraint restricts the ability to input all content into the prompt simultaneously, leading to potential loss of critical context and details. This necessitates the development of sophisticated strategies for selectively retrieving and processing relevant sections of the document. Techniques such as chunking the document into manageable parts, employing summarization methods, and using external retrieval systems are crucial to address these challenges. Understanding and mitigating these limitations are essential for designing effective QA systems that leverage the full potential of LLMs while navigating their inherent constraints.

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-required-libraries">Installing required libraries</a></li>
#             <li><a href="#Importing-required-libraries">Importing required libraries</a></li>
#         </ol>
#     </li>
#     <li><a href="#Build-LLM">Build LLM</a></li>
#     <li><a href="#Load-source-document">Load source document</a></li>
#     <li>
#         <a href="#Limitation-of-retrieve-directly-from-full-document">Limitation of retrieve directly from full document</a>
#         <ol>
#             <li><a href="#Context-length">Context length</a></li>
#             <li><a href="#LangChain-prompt-template">LangChain prompt template</a></li>
#             <li><a href="#Use-mixtral-model">Use mixtral model</a></li>
#             <li><a href="#Use-Llama-3-model">Use Llama 3 model</a></li>
#             <li><a href="#Use-one-piece-of-information">Use one piece of information</a></li>
#         </ol>
#     </li>
# </ol>
#
# <a href="#Exercises">Exercises</a>
# <ol>
#     <li><a href="#Exercise-1---Change-to-use-another-LLM">Exercise 1 - Change to use another LLM</a></li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Explain the concept of context length for LLMs.
#  - Recognize the limitations of retrieving information when inputting the entire content of a document into a prompt.

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, you will use the following libraries:
#
# *   [`ibm-watson-ai`](https://ibm.github.io/watson-machine-learning-sdk/index.html) for using LLMs from IBM's watsonx.ai.
# *   [`langchain`, `langchain-ibm`, `langchain-community`](https://www.langchain.com/) for using relevant features from LangChain.

# %% [markdown]
# ### Installing required libraries
#
# The following required libraries are __not__ preinstalled in the Skills Network Labs environment. __You must run the following cell__ to install them:
#
# **Note:** The version is being pinned here to specify the version. It's recommended that you do this as well. Even if the library is updated in the future, the installed library could still support this lab work.
#
# This might take approximately 1 minute.
#
# As `%%capture` is used to capture the installation, you won't see the output process. After the installation is completed, you will see a number beside the cell.

# %%
#After executing the cell,please RESTART the kernel and run all the cells.
# !pip install --user "ibm-watsonx-ai==1.0.10"
# !pip install --user "langchain==0.2.6" 
# !pip install --user "langchain-ibm==0.1.8"
# !pip install --user "langchain-community==0.2.1"
# Out:
# Collecting ibm-watsonx-ai==1.0.10
#   Downloading ibm_watsonx_ai-1.0.10-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.0.10) (2.32.3)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.0.10) (2.2.3)
# Collecting pandas<2.2.0,>=0.24.2 (from ibm-watsonx-ai==1.0.10)
#   Downloading pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.0.10) (2025.1.31)
# Collecting lomond (from ibm-watsonx-ai==1.0.10)
#   Downloading lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tabulate in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.0.10) (0.9.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.0.10) (24.1)
# Collecting ibm-cos-sdk<2.14.0,>=2.12.0 (from ibm-watsonx-ai==1.0.10)
#   Downloading ibm-cos-sdk-2.13.6.tar.gz (58 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai==1.0.10) (7.0.1)
# Collecting ibm-cos-sdk-core==2.13.6 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10)
#   Downloading ibm-cos-sdk-core-2.13.6.tar.gz (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      ------------------- -------------------- 0.5/1.1 MB 509.0 kB/s eta 0:00:02
#      ------------------- -------------------- 0.5/1.1 MB 509.0 kB/s eta 0:00:02
#      ------------------- -------------------- 0.5/1.1 MB 509.0 kB/s eta 0:00:02
#      ---------------------------- ----------- 0.8/1.1 MB 508.5 kB/s eta 0:00:01
#      ---------------------------- ----------- 0.8/1.1 MB 508.5 kB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 548.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ibm-cos-sdk-s3transfer==2.13.6 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10)
#   Downloading ibm-cos-sdk-s3transfer-2.13.6.tar.gz (139 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (2.9.0.post0)
# Collecting requests (from ibm-watsonx-ai==1.0.10)
#   Downloading requests-2.32.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai==1.0.10) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai==1.0.10) (3.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->ibm-watsonx-ai==1.0.10) (3.17.0)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from lomond->ibm-watsonx-ai==1.0.10) (1.16.0)
# Downloading ibm_watsonx_ai-1.0.10-py3-none-any.whl (936 kB)
#    ---------------------------------------- 0.0/936.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/936.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/936.7 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/936.7 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.13.6-py3-none-any.whl size=661472 sha256=d2db4d56ae92e87f0ba12c68e37329504a42c380c4885e726076b09a3b05ca9a
#   Stored in directory: c:\users\andre\appdata\local\pip\cache\wheels\3f\11\58\646f89b99861739fce853f8776e5037d0f704d5d9623a07f7c
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): started
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.13.6-py3-none-any.whl size=90212 sha256=8ea877c62d16305858c9b2e3f9d3f212b1ecc722ecb7d8b4267e8530d4f6f8d9
#   Stored in directory: c:\users\andre\appdata\local\pip\cache\wheels\52\9d\54\09e4008d97d8a2e38ecff56eea0d60ef27a77d9a313cc77360
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: requests, lomond, pandas, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watsonx-ai
# Successfully installed ibm-cos-sdk-2.13.6 ibm-cos-sdk-core-2.13.6 ibm-cos-sdk-s3transfer-2.13.6 ibm-watsonx-ai-1.0.10 lomond-0.3.3 pandas-2.1.4 requests-2.32.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aext-assistant-server 4.1.0 requires anaconda-cloud-auth>=0.7.1, which is not installed.
# Collecting langchain==0.2.6
#   Downloading langchain-0.2.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.6) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.6) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.6) (3.10.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain==0.2.6) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain==0.2.6) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain==0.2.6) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.6) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain==0.2.6) (2.11.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain==0.2.6) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.6) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (1.11.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.6) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1->langchain==0.2.6) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1->langchain==0.2.6) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.6) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.6) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.6) (3.0.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (2.1)
# Downloading langchain-0.2.6-py3-none-any.whl (975 kB)
#    ---------------------------------------- 0.0/975.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/975.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/975.5 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/975.5 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/975.5 kB ? eta -:--:--
#    -------------------- ----------------- 524.3/975.5 kB 508.0 kB/s eta 0:00:01
#    -------------------- ----------------- 524.3/975.5 kB 508.0 kB/s eta 0:00:01
#    -------------------- ----------------- 524.3/975.5 kB 508.0 kB/s eta 0:00:01
#    ------------------------------ ------- 786.4/975.5 kB 500.8 kB/s eta 0:00:01
#    ------------------------------ ------- 786.4/975.5 kB 500.8 kB/s eta 0:00:01
#    -------------------------------------- 975.5/975.5 kB 507.3 kB/s eta 0:00:00
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.17
#     Uninstalling langchain-0.2.17:
#       Successfully uninstalled langchain-0.2.17
# Successfully installed langchain-0.2.6
#   WARNING: The script langchain-server.exe is installed in 'C:\Users\andre\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting langchain-ibm==0.1.8
#   Downloading langchain_ibm-0.1.8-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.0.8 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-ibm==0.1.8) (1.0.10)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-ibm==0.1.8) (0.2.43)
# Requirement already satisfied: requests in c:\users\andre\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.32.2)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.2.3)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.1.4)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2025.1.31)
# Requirement already satisfied: lomond in c:\users\andre\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (0.3.3)
# Requirement already satisfied: tabulate in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (0.9.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (24.1)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (7.0.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (0.1.147)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (2.11.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (4.13.2)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\users\andre\appdata\roaming\python\python312\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (1.0.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (3.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (3.17.0)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.8) (1.16.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.8) (0.14.0)
# Downloading langchain_ibm-0.1.8-py3-none-any.whl (17 kB)
# Installing collected packages: langchain-ibm
# Successfully installed langchain-ibm-0.1.8
# Requirement already satisfied: langchain-community==0.2.1 in c:\users\andre\appdata\roaming\python\python312\site-packages (0.2.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.1) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.1) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.1) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.1) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.1) (0.2.6)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.1) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.1) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.1) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.1) (2.32.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.1) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.1) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.1) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.1) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.1) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.1) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.1) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.1) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community==0.2.1) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community==0.2.1) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community==0.2.1) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community==0.2.1) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community==0.2.1) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\andre\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.1) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.1) (3.0.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community==0.2.1) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community==0.2.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\andre\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community==0.2.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\andre\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community==0.2.1) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.1) (1.0.0)

# %% [markdown]
# After you install the libraries, restart your kernel. You can do that by clicking the **Restart the kernel** icon.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/build-a-hotdog-not-hotdog-classifier-guided-project/images/Restarting_the_Kernel.png" width="70%" alt="Restart kernel">

# %% [markdown]
# ### Importing required libraries

# %%
# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_community.document_loaders import TextLoader
from langchain_ibm import WatsonxLLM

# %% [markdown]
# ## Build LLM

# %% [markdown]
# Here, you will create a function that interacts with the watsonx.ai API, enabling you to utilize various models available.
#
# You just need to input the model ID in string format, then it will return you with the LLM object. You can use it to invoke any queries. A list of model IDs can be found in [here](https://ibm.github.io/watsonx-ai-python-sdk/fm_model.html).

# %%
def llm_model(model_id):
    parameters = {
        GenParams.MAX_NEW_TOKENS: 256,  # this controls the maximum number of tokens in the generated output
        GenParams.TEMPERATURE: 0.5, # this randomness or creativity of the model's responses
    }
    
    credentials = {
        "url": "https://us-south.ml.cloud.ibm.com"
    }
    
    project_id = "skills-network"
    
    model = ModelInference(
        model_id=model_id,
        params=parameters,
        credentials=credentials,
        project_id=project_id
    )
    
    llm = WatsonxLLM(watsonx_model = model)
    return llm

# %% [markdown]
# Let's try to invoke an example query.

# %%
llama_llm = llm_model('meta-llama/llama-3-3-70b-instruct')
# Out:
# '`api_key` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llama_llm = llm_model('meta-llama/llama-3-3-70b-instruct')
#
# Cell In[3], line 13, in llm_model(model_id)
#       7 credentials = {
#       8     "url": "https://us-south.ml.cloud.ibm.com"
#       9 }
#      11 project_id = "skills-network"
# ---> 13 model = ModelInference(
#      14     model_id=model_id,
#      15     params=parameters,
#      16     credentials=credentials,
#      17     project_id=project_id
#      18 )
#      20 llm = WatsonxLLM(watsonx_model = model)
#      21 return llm
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ibm_watsonx_ai\foundation_models\inference\model_inference.py:148, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate)
#     145 if credentials:
#     146     from ibm_watsonx_ai import APIClient
# --> 148     self._client = APIClient(credentials, verify=verify)
#     149 elif api_client:
#     150     self._client = api_client
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ibm_watsonx_ai\client.py:223, in APIClient.__init__(self, credentials, project_id, space_id, verify, **kwargs)
#     218             raise WMLClientError(
#     219                 Messages.get_message(message_id="invalid_cloud_scenario_url")
#     220             )
#     222     if not self._is_IAM():
# --> 223         raise WMLClientError(
#     224             Messages.get_message(message_id="apikey_not_provided")
#     225         )
#     226 else:
#     227     if (
#     228         "icp" == self.credentials.instance_id.lower()
#     229         or "openshift" == self.credentials.instance_id.lower()
#     230     ):
#
# WMLClientError: '`api_key` for IAM token is not provided in credentials for the client'

# %%
llama_llm.invoke("How are you?")

# %% [markdown]
# ## Load source document

# %% [markdown]
# A document has been prepared here.

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/d_ahNwb1L2duIxBR6RD63Q/state-of-the-union.txt"

# %% [markdown]
# Use `TextLoader` to load the text.

# %%
loader = TextLoader("state-of-the-union.txt")

# %%
data = loader.load()

# %% [markdown]
# Let's take a look at the document.

# %%
content = data[0].page_content
content

# %% [markdown]
# ## Limitation of retrieve directly from full document

# %% [markdown]
# ### Context length

# %% [markdown]
# Before you explore the limitations of directly retrieving information from a full document, you need to understand a concept called `context length`.
#
# `Context length` in LLMs refers to the amount of text or information (prompt) that the model can consider when processing or generating output. LLMs have a fixed context length, meaning they can only take into account a limited amount of text at a time.

# %% [markdown]
# So, how long is your source document here? The answer is 8,235 tokens, which you calculated using this [platform](https://platform.openai.com/tokenizer).

# %% [markdown]
# ### LangChain prompt template

# %% [markdown]
# A prompt template has been set up using LangChain to make it reusable.
#
# In this template, you will define two input variables:
# - `content`: This variable will hold all the content from the entire source document at once.
# - `question`: This variable will capture the user's query.

# %%
template = """According to the document content here 
            {content},
            answer this question 
            {question}.
            Do not try to make up the answer.
                
            YOUR RESPONSE:
"""

prompt_template = PromptTemplate(template=template, input_variables=['content', 'question'])
prompt_template

# %% [markdown]
# ### Use mixtral model

# %% [markdown]
# Since the context window length of the mixtral model is longer than your source document, you can assume it can retrieve relevant information for the query when you input the whole document into the prompt.

# %% [markdown]
# First, let's build a mixtral model.

# %%
mixtral_llm = llm_model('mistralai/mixtral-8x7b-instruct-v01')

# %% [markdown]
# Then, create a query chain.

# %%
query_chain = LLMChain(llm=mixtral_llm, prompt=prompt_template)

# %% [markdown]
# Then, set the query and get the answer.

# %%
query = "It is in which year of our nation?"
response = query_chain.invoke(input={'content': content, 'question': query})
print(response['text'])

# %% [markdown]
# Ypu have asked a question whose answer appears at the very end of the document. Despite this, the LLM was still able to answer it correctly because the model's context window is long enough to accommodate the entire content of the document.

# %% [markdown]
# ### Use Llama 3 model

# %% [markdown]
# Now, let's try using Llama3 model.

# %% [markdown]
# First, create a query chain.

# %%
query_chain = LLMChain(llm=llama_llm, prompt=prompt_template)
query_chain

# %% [markdown]
# Then, use the query chain (the code is shown below) to invoke the LLM, which will answer the same query as before based on the entire document's content.

# %%
query = "It is in which year of our nation?"
response = query_chain.invoke(input={'content': content, 'question': query})
print(response['text'])

# %% [markdown]
# Now you can see It can also provide the correct answer.

# %% [markdown]
# #### Take away

# %% [markdown]
# If the document is much longer than the LLM's context length, it is important and necessary to cut the document into chunks, index them, and then let the LLM retrieve the relevant information accurately and efficiently.
#
# In the next lesson, you will learn how to perform these operations using LangChain.

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise 1 - Change to use another LLM

# %% [markdown]
# Try to use another LLM to see if error occurs. For example, try using `'ibm/granite-3-8b-instruct'`.

# %%
# Your code here

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# granite_llm = llm_model('ibm/granite-3-8b-instruct')
# query_chain = LLMChain(llm=granite_llm, prompt=prompt_template)
# query = "It is in which year of our nation?"
# response = query_chain.invoke(input={'content': content, 'question': query})
# print(response['text'])
# ```
#
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Kang Wang](https://author.skills.network/instructors/kang_wang)
#
# Kang Wang is a Data Scientist in IBM. He is also a PhD Candidate in the University of Waterloo.
#
# [Ricky Shi](https://author.skills.network/instructors/ricky_shi)
#
# Ricky Shi is a Data Scientist at IBM.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Joseph Santarcangelo](https://author.skills.network/instructors/joseph_santarcangelo),
#
# Joseph has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
